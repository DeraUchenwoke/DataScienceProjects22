# %% [markdown]
# # Exercise 1

# %% [markdown]
# ### Creat DataFrames from scratch
#
#
# 1.1 Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %% [markdown]
# 1.2 Create a data dictionary that looks like the Dataframe below:

# %%
d = {
    'name': ['Wii Sport', 'Super Mario Bros', 'Pokemon Red', 'Nintendogs'], 
    'Platform': ['Wii', 'NES', 'GB', 'DS'],
    'EU_Sale': [29.02, 3.58, 8.89, 11.00],
    'Genre' : ['Sports', 'Platform', 'Role-Playing', 'Simulation']
}
d
# Out:
# {'name': ['Wii Sport', 'Super Mario Bros', 'Pokemon Red', 'Nintendogs'],
#  'Platform': ['Wii', 'NES', 'GB', 'DS'],
#  'EU_Sale': [29.02, 3.58, 8.89, 11.0],
#  'Genre': ['Sports', 'Platform', 'Role-Playing', 'Simulation']}

# %% [markdown]
# 1.3 Assign it to a variable called vgsale

# %%
vgsale = pd.DataFrame(d)
vgsale
# Out:
#                name Platform  EU_Sale         Genre
# 0         Wii Sport      Wii    29.02        Sports
# 1  Super Mario Bros      NES     3.58      Platform
# 2       Pokemon Red       GB     8.89  Role-Playing
# 3        Nintendogs       DS    11.00    Simulation

# %% [markdown]
# 1.4 Place  the order of the columns as name, Genre, Platform, EU_Sale

# %%
vgsale = vgsale[['name', 'Genre', 'Platform', 'EU_Sale']]
vgsale
# Out:
#                name         Genre Platform  EU_Sale
# 0         Wii Sport        Sports      Wii    29.02
# 1  Super Mario Bros      Platform      NES     3.58
# 2       Pokemon Red  Role-Playing       GB     8.89
# 3        Nintendogs    Simulation       DS    11.00

# %% [markdown]
# 1.5 Add another column called Year, and insert 2006, 1985, 1996, 2005.

# %%
vgsale['Year'] = [2006, 1985, 1996, 2005]
vgsale
# Out:
# C:\Users\uchid\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                name         Genre Platform  EU_Sale  Year
# 0         Wii Sport        Sports      Wii    29.02  2006
# 1  Super Mario Bros      Platform      NES     3.58  1985
# 2       Pokemon Red  Role-Playing       GB     8.89  1996
# 3        Nintendogs    Simulation       DS    11.00  2005

# %% [markdown]
# 1.6 Present the type of each column. You may need to check the usage of [**.dtype**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dtypes.html)

# %%
vgsale.dtypes
# Out:
# name         object
# Genre        object
# Platform     object
# EU_Sale     float64
# Year          int64
# dtype: object

# %% [markdown]
# 1.7 save the above DataFrame to a csv file.

# %%
vgsale.to_csv('vgsale.csv')

# %% [markdown]
# # Exercise 2

# %% [markdown]
# # Importing and Knowing your Data

# %% [markdown]
# 2.1 Import the necessary libraries

# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import os
# Out:
# c:\Users\uchid\OneDrive\Documents\Data Science MSc\Modules\Sem 1\Programming for Data Science\DataScienceProjects22\main\Pandas_1

# %% [markdown]
# 2.2 Import the **movie_metadata** dataset and assign it to a variable called movie.

# %%
currDirectory = os.getcwd()
df = pd.read_csv(currDirectory + '\\data\\movie_metadata.csv')
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# 2.3 See the first 8 entries

# %%
df.head(8)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
# 5  Color     Andrew Stanton                   462.0     132.0
# 6  Color          Sam Raimi                   392.0     156.0
# 7  Color       Nathan Greno                   324.0     100.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# ...

# %% [markdown]
# 2.4 Set the 'director_name' column as index of the dataframe. Please check the usage of [**.set_index**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.set_index.html).

# %%
df.set_index('director_name', inplace=True)
df
# Out:
#                    color  num_critic_for_reviews  duration  \
# director_name
# James Cameron      Color                   723.0     178.0
# Gore Verbinski     Color                   302.0     169.0
# Sam Mendes         Color                   602.0     148.0
# Christopher Nolan  Color                   813.0     164.0
# Doug Walker          NaN                     NaN       NaN
# ...                  ...                     ...       ...
# Scott Smith        Color                     1.0      87.0
# NaN                Color                    43.0      43.0
# Benjamin Roberds   Color                    13.0      76.0
# Daniel Hsia        Color                    14.0     100.0
# Jon Gunn           Color                    43.0      90.0
#
#                    director_facebook_likes  actor_3_facebook_likes  \
# director_name
# James Cameron                          0.0                   855.0
# Gore Verbinski                       563.0                  1000.0
# ...

# %% [markdown]
# 2.5 What is the number of observations in the dataset?

# %%
# Solution 1

df.info()
# index number shows number of entries/observations.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5043 entries, James Cameron to Jon Gunn
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   num_critic_for_reviews     4993 non-null   float64
#  2   duration                   5028 non-null   float64
#  3   director_facebook_likes    4939 non-null   float64
#  4   actor_3_facebook_likes     5020 non-null   float64
#  5   actor_2_name               5030 non-null   object
#  6   actor_1_facebook_likes     5036 non-null   float64
#  7   gross                      4159 non-null   float64
#  8   genres                     5043 non-null   object
#  9   actor_1_name               5036 non-null   object
#  10  movie_title                5043 non-null   object
#  11  num_voted_users            5043 non-null   int64
#  12  cast_total_facebook_likes  5043 non-null   int64
# ...

# %%
# Solution 2
df.shape

# number of rows is equivalent number of observations
# To get the rows by itself do: df.shape[0]
# Out:
# (5043, 27)

# %% [markdown]
# 2.6  What is the number of columns in the dataset?

# %%
df.shape[1]
# Out:
# 27

# %% [markdown]
# 2.7 Print the name of all the columns (You may need to check the usage of [.columns](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.columns.html)).

# %%
df.columns
# Out:
# Index(['color', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# 2.8 Print the columns 'movie_title' and 'director_facebook_likes':

# %%
df[['movie_title', 'director_facebook_likes']]
# Out:
#                                                          movie_title  \
# director_name
# James Cameron                                                Avatar
# Gore Verbinski             Pirates of the Caribbean: At World's End
# Sam Mendes                                                  Spectre
# Christopher Nolan                             The Dark Knight Rises
# Doug Walker        Star Wars: Episode VII - The Force Awakens    ...
# ...                                                              ...
# Scott Smith                                 Signed Sealed Delivered
# NaN                                       The Following
# Benjamin Roberds                               A Plague So Pleasant
# Daniel Hsia                                        Shanghai Calling
# Jon Gunn                                          My Date with Drew
#
#                    director_facebook_likes
# director_name
# James Cameron                          0.0
# ...

# %% [markdown]
# 2.9 Select the 'actor_1_name', 'actor_2_name' and 'actor_3_name' columns from Sam Mendes and Doug Walker

# %%
# using .loc[]
actors = df.loc[['Sam Mendes', 'Doug Walker'], ['actor_1_name', 'actor_2_name', 'actor_3_name']]
actors
# Out:
#                     actor_1_name          actor_2_name      actor_3_name
# director_name
# Sam Mendes       Christoph Waltz          Rory Kinnear  Stephanie Sigman
# Sam Mendes         Albert Finney         Helen McCrory      Rory Kinnear
# Sam Mendes             Tom Hanks  Jennifer Jason Leigh        Liam Aiken
# Sam Mendes       Jake Gyllenhaal        Brian Geraghty    James Morrison
# Sam Mendes     Leonardo DiCaprio          Kate Winslet        Joe Komara
# Sam Mendes      Catherine O'Hara          Jim Gaffigan      Carmen Ejogo
# Sam Mendes          Kevin Spacey       Peter Gallagher          Ara Celi
# Sam Mendes         Albert Finney         Helen McCrory      Rory Kinnear
# Doug Walker          Doug Walker            Rob Walker               NaN

# %% [markdown]
# 2.10 Select the rows 3 to 7 and the columns 3 to 6

# %%
# using .iloc

df1 = df.iloc[2:7, 2:6]
df1
# Out:
#                    duration  director_facebook_likes  actor_3_facebook_likes  \
# director_name
# Sam Mendes            148.0                      0.0                   161.0
# Christopher Nolan     164.0                  22000.0                 23000.0
# Doug Walker             NaN                    131.0                     NaN
# Andrew Stanton        132.0                    475.0                   530.0
# Sam Raimi             156.0                      0.0                  4000.0
#
#                       actor_2_name
# director_name
# Sam Mendes            Rory Kinnear
# Christopher Nolan   Christian Bale
# Doug Walker             Rob Walker
# Andrew Stanton     Samantha Morton
# Sam Raimi             James Franco

# %% [markdown]
# 2.11 Select every row up to the 4th row and all columns

# %%
# using .iloc
df2 = df.iloc[0:4, :]
df2
# Out:
#                    color  num_critic_for_reviews  duration  \
# director_name
# James Cameron      Color                   723.0     178.0
# Gore Verbinski     Color                   302.0     169.0
# Sam Mendes         Color                   602.0     148.0
# Christopher Nolan  Color                   813.0     164.0
#
#                    director_facebook_likes  actor_3_facebook_likes  \
# director_name
# James Cameron                          0.0                   855.0
# Gore Verbinski                       563.0                  1000.0
# Sam Mendes                             0.0                   161.0
# Christopher Nolan                  22000.0                 23000.0
#
#                        actor_2_name  actor_1_facebook_likes        gross  \
# director_name
# James Cameron      Joel David Moore                  1000.0  760505847.0
# Gore Verbinski        Orlando Bloom                 40000.0  309404152.0
# ...

# %% [markdown]
# 2.12 Select rows where movie.duration is greater than 100

# %%
df3 = df[df['duration'] > 100]
df3
# Out:
#                    color  num_critic_for_reviews  duration  \
# director_name
# James Cameron      Color                   723.0     178.0
# Gore Verbinski     Color                   302.0     169.0
# Sam Mendes         Color                   602.0     148.0
# Christopher Nolan  Color                   813.0     164.0
# Andrew Stanton     Color                   462.0     132.0
# ...                  ...                     ...       ...
# Alex Kendrick      Color                     5.0     120.0
# Brandon Landers      NaN                     NaN     143.0
# John Waters        Color                    73.0     108.0
# Olivier Assayas    Color                    81.0     110.0
# Kiyoshi Kurosawa   Color                    78.0     111.0
#
#                    director_facebook_likes  actor_3_facebook_likes  \
# director_name
# James Cameron                          0.0                   855.0
# Gore Verbinski                       563.0                  1000.0
# ...

# %% [markdown]
# 2.13 Select rows where movie.duration is greater than 150 or less than 100

# %%
df4 = df[(df['duration'] > 150) | (df['duration'] < 100)]
df4
# Out:
#                    color  num_critic_for_reviews  duration  \
# director_name
# James Cameron      Color                   723.0     178.0
# Gore Verbinski     Color                   302.0     169.0
# Christopher Nolan  Color                   813.0     164.0
# Sam Raimi          Color                   392.0     156.0
# David Yates        Color                   375.0     153.0
# ...                  ...                     ...       ...
# Edward Burns       Color                    14.0      95.0
# Scott Smith        Color                     1.0      87.0
# NaN                Color                    43.0      43.0
# Benjamin Roberds   Color                    13.0      76.0
# Jon Gunn           Color                    43.0      90.0
#
#                    director_facebook_likes  actor_3_facebook_likes  \
# director_name
# James Cameron                          0.0                   855.0
# Gore Verbinski                       563.0                  1000.0
# ...

# %% [markdown]
# 2.14 Select all the movies that are not marked as "Color"

# %%
df5 = df[df['color'] != 'Color']
df5
# Out:
#                               color  num_critic_for_reviews  duration  \
# director_name
# Doug Walker                     NaN                     NaN       NaN
# Michael Bay         Black and White                   191.0     184.0
# Lee Tamahori        Black and White                   264.0     133.0
# Martin Scorsese     Black and White                   267.0     170.0
# Michael Mann        Black and White                   174.0     165.0
# ...                             ...                     ...       ...
# Kevin Smith         Black and White                   136.0     102.0
# Richard Linklater   Black and White                    61.0     100.0
# Brandon Landers                 NaN                     NaN     143.0
# Jim Chuchu          Black and White                     6.0      60.0
# Ivan Kavanagh       Black and White                    12.0      83.0
#
#                    director_facebook_likes  actor_3_facebook_likes  \
# director_name
# ...
